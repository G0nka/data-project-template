# %%
###Let's start by importing all needed libraries

from sqlalchemy import create_engine
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
import json 
import requests

# %%
### 1.- CONNECTION TO THE DATABASE .db

# connection string'

sqlitedb_rel_path = '../data/raw/raw_data_project_m1.db'
conn_str = f'sqlite:///{sqlitedb_rel_path}'

engine = create_engine(conn_str)

# %%
# Import initial data from the db:uuid , age , countries...
initial_df = pd.read_sql_query("""
SELECT personal_info.uuid, normalized_job_code ,age , country_code FROM personal_info
INNER JOIN country_info ON personal_info.uuid = country_info.uuid
INNER JOIN career_info ON personal_info.uuid = career_info.uuid;
""", engine)

# %%
initial_df.head()
# Out:
#                                    uuid               normalized_job_code  \
# 0  f6e7ee00-deac-0133-4de8-0a81e8b09a82                              None
# 1  54f0f1c0-dda1-0133-a559-0a81e8b09a82  861a9b9151e11362eb3c77ca914172d0
# 2  83127080-da3d-0133-c74f-0a81e8b09a82                              None
# 3  15626d40-db13-0133-ea5c-0a81e8b09a82  049a3f3a2b5f85cb2971ba77ad66e10c
# 4  24954a70-db98-0133-4a64-0a81e8b09a82  f4b2fb1aa40f661488e2782b6d57ad2f
#
#             age country_code
# 0  61 years old           AT
# 1  57 years old           AT
# 2  32 years old           AT
# 3  45 years old           AT
# 4  41 years old           AT

# %%
### 2.- CONNECTION TO THE API

# Lets prepare the key before the searching:
job_code_unique = initial_df['normalized_job_code'].unique()

# %%
len(job_code_unique)
# Out:
# 157

# %%
job_code_unique[:5]
# Out:
# array([None, '861a9b9151e11362eb3c77ca914172d0',
#        '049a3f3a2b5f85cb2971ba77ad66e10c',
#        'f4b2fb1aa40f661488e2782b6d57ad2f',
#        '27af8700f5577cec835acee2cb90a2ff'], dtype=object)

# %%
# Lets get the information from the API
job_titles = {}
#code = "8a7a3f1bce0958ae9f090683e5a925b7"
for code in job_code_unique[1:]:
    results = requests.get(f'http://api.dataatwork.org/v1/jobs/{code}').json()
    job = results['title']
    job_titles[code] = job

# %%
# I am always more comfortable working with pandas df...
job_titles_df = pd.DataFrame(job_titles.items() ,columns=['normalized_job_code','Job Title'])
job_titles_df.head()
# Out:
#                 normalized_job_code                          Job Title
# 0  861a9b9151e11362eb3c77ca914172d0  Automatic Data Processing Planner
# 1  049a3f3a2b5f85cb2971ba77ad66e10c                   Data Coordinator
# 2  f4b2fb1aa40f661488e2782b6d57ad2f                 Database Developer
# 3  27af8700f5577cec835acee2cb90a2ff              Data Entry Specialist
# 4  c1b670eba9ccb65e7c99f7da116d5b9c                 Database Architect

# %%
### 3.- WEBSCRAPING TO GET THE COUNTRY CODES:

url = 'https://ec.europa.eu/eurostat/statistics-explained/index.php/Glossary:Country_codes'
html = requests.get(url).content
html[0:600]
# Out:
# b'\xef\xbb\xbf<!DOCTYPE html>\n<html lang="en" dir="ltr" class="client-nojs">\n<head>\n<meta http-equiv="X-UA-Compatible" content="Ie=Edge,chrome=1"/> <meta charset="UTF-8" /><title>Glossary:Country codes - Statistics Explained</title>\n<meta name="generator" content="MediaWiki 1.22.5" />\n<link rel="shortcut icon" href="https://ec.europa.eu/eurostat/estat-theme/images/favicon.ico" />\n<link rel="search" type="application/opensearchdescription+xml" href="/eurostat/statistics-explained/opensearch_desc.php" title="Statistics Explained (en)" />\n<link rel="EditURI" type="application/rsd+xml" href="https://ec.europ'

# %%
countries_raw = soup.find('table',{'width':'80%'}).text
countries_raw
# Out:
# '\n\nBelgium\n\n(BE)\n\nGreece\n\n(EL)\n\nLithuania\n\n(LT)\n\nPortugal\n\n(PT)\n\n\nBulgaria\n\n(BG)\n\nSpain\n\n(ES)\n\nLuxembourg\n\n(LU)\n\nRomania\n\n(RO)\n\n\nCzechia\n\n(CZ)\n\nFrance\n\n(FR)\n\nHungary\n\n(HU)\n\nSlovenia\n\n(SI)\n\n\nDenmark\n\n(DK)\n\nCroatia\n\n(HR)\n\nMalta\n\n(MT)\n\nSlovakia\n\n(SK)\n\n\nGermany\n\n(DE)\n\nItaly\n\n(IT)\n\nNetherlands\n\n(NL)\n\nFinland\n\n(FI)\n\n\nEstonia\n\n(EE)\n\nCyprus\n\n(CY)\n\nAustria\n\n(AT)\n\nSweden\n\n(SE)\n\n\nIreland\n\n(IE)\n\nLatvia\n\n(LV)\n\nPoland\n\n(PL)\n'

# %%
countries_raw = countries_raw.replace("\n","")

# %%
countries_raw
# Out:
# 'Belgium(BE)Greece(EL)Lithuania(LT)Portugal(PT)Bulgaria(BG)Spain(ES)Luxembourg(LU)Romania(RO)Czechia(CZ)France(FR)Hungary(HU)Slovenia(SI)Denmark(DK)Croatia(HR)Malta(MT)Slovakia(SK)Germany(DE)Italy(IT)Netherlands(NL)Finland(FI)Estonia(EE)Cyprus(CY)Austria(AT)Sweden(SE)Ireland(IE)Latvia(LV)Poland(PL)'

# %%
countries_raw = countries_raw.split(')')

# %%
countries_raw
# Out:
# ['Belgium(BE',
#  'Greece(EL',
#  'Lithuania(LT',
#  'Portugal(PT',
#  'Bulgaria(BG',
#  'Spain(ES',
#  'Luxembourg(LU',
#  'Romania(RO',
#  'Czechia(CZ',
#  'France(FR',
#  'Hungary(HU',
#  'Slovenia(SI',
#  'Denmark(DK',
#  'Croatia(HR',
#  'Malta(MT',
#  'Slovakia(SK',
#  'Germany(DE',
#  'Italy(IT',
#  'Netherlands(NL',
#  'Finland(FI',
#  'Estonia(EE',
#  'Cyprus(CY',
#  'Austria(AT',
#  'Sweden(SE',
#  'Ireland(IE',
#  'Latvia(LV',
#  'Poland(PL',
#  '']

# %%
list_countries = [i.split('(') for i in countries_raw]
country_codes_df = pd.DataFrame(list_countries, columns=('Country','country_code'))

# %%
#Life is better with a df...
country_codes_df
# Out:
#         Country country_code
# 0       Belgium           BE
# 1        Greece           EL
# 2     Lithuania           LT
# 3      Portugal           PT
# 4      Bulgaria           BG
# 5         Spain           ES
# 6    Luxembourg           LU
# 7       Romania           RO
# 8       Czechia           CZ
# 9        France           FR
# 10      Hungary           HU
# 11     Slovenia           SI
# 12      Denmark           DK
# 13      Croatia           HR
# 14        Malta           MT
# 15     Slovakia           SK
# 16      Germany           DE
# 17        Italy           IT
# 18  Netherlands           NL
# 19      Finland           FI
# 20      Estonia           EE
# 21       Cyprus           CY
# 22      Austria           AT
# 23       Sweden           SE
# 24      Ireland           IE
# 25       Latvia           LV
# 26       Poland           PL
# 27                      None

# %%
final_df = pd.merge(initial_df,  
                      job_titles_df,  
                      on ='normalized_job_code',  
                      how ='inner')

# %%
definitive_df = pd.merge(final_df,  
                      country_codes_df,  
                      on ='country_code',  
                      how ='inner')

# %%
definitive_df.head()
# Out:
#                                    uuid               normalized_job_code  \
# 0  54f0f1c0-dda1-0133-a559-0a81e8b09a82  861a9b9151e11362eb3c77ca914172d0
# 1  cf24ed60-da3f-0133-0034-0a81e8b09a82  861a9b9151e11362eb3c77ca914172d0
# 2  15626d40-db13-0133-ea5c-0a81e8b09a82  049a3f3a2b5f85cb2971ba77ad66e10c
# 3  ca3f65f0-d92b-0133-3959-0a81e8b09a82  049a3f3a2b5f85cb2971ba77ad66e10c
# 4  24954a70-db98-0133-4a64-0a81e8b09a82  f4b2fb1aa40f661488e2782b6d57ad2f
#
#             age country_code                          Job Title  Country
# 0  57 years old           AT  Automatic Data Processing Planner  Austria
# 1  48 years old           AT  Automatic Data Processing Planner  Austria
# 2  45 years old           AT                   Data Coordinator  Austria
# 3  46 years old           AT                   Data Coordinator  Austria
# 4  41 years old           AT                 Database Developer  Austria

# %%
def fix_age (age):
    if 'years old' in age:
        born_y = 2016 - int(re.sub("[^\d]", "", age)) 
    else:
        born_y = int(age)
        
    right_age = 2021 - born_y     
    
    return right_age 

definitive_df['age'] = definitive_df.apply(lambda x: fix_age(x['age']), axis=1 )

# %%
definitive_df.head()
# Out:
#                                    uuid               normalized_job_code  \
# 0  54f0f1c0-dda1-0133-a559-0a81e8b09a82  861a9b9151e11362eb3c77ca914172d0
# 1  cf24ed60-da3f-0133-0034-0a81e8b09a82  861a9b9151e11362eb3c77ca914172d0
# 2  15626d40-db13-0133-ea5c-0a81e8b09a82  049a3f3a2b5f85cb2971ba77ad66e10c
# 3  ca3f65f0-d92b-0133-3959-0a81e8b09a82  049a3f3a2b5f85cb2971ba77ad66e10c
# 4  24954a70-db98-0133-4a64-0a81e8b09a82  f4b2fb1aa40f661488e2782b6d57ad2f
#
#    age country_code                          Job Title  Country
# 0   62           AT  Automatic Data Processing Planner  Austria
# 1   53           AT  Automatic Data Processing Planner  Austria
# 2   50           AT                   Data Coordinator  Austria
# 3   51           AT                   Data Coordinator  Austria
# 4   46           AT                 Database Developer  Austria

# %%
def group_age (age):
    if age <= 25:
         age_group = '(18-25)' 
    elif age <= 35:
        age_group = '[30-35)'
    elif age <= 45:
        age_group = '[40-45)'
    elif age <= 55:
        age_group = '[45-55)'
    else:
        age_group = '[55-70)'
    
    return age_group

definitive_df['Age Group'] = definitive_df.apply(lambda x: group_age(x['age']), axis=1 )

# %%
definitive_df.head()
# Out:
#                                    uuid               normalized_job_code  \
# 0  54f0f1c0-dda1-0133-a559-0a81e8b09a82  861a9b9151e11362eb3c77ca914172d0
# 1  cf24ed60-da3f-0133-0034-0a81e8b09a82  861a9b9151e11362eb3c77ca914172d0
# 2  15626d40-db13-0133-ea5c-0a81e8b09a82  049a3f3a2b5f85cb2971ba77ad66e10c
# 3  ca3f65f0-d92b-0133-3959-0a81e8b09a82  049a3f3a2b5f85cb2971ba77ad66e10c
# 4  24954a70-db98-0133-4a64-0a81e8b09a82  f4b2fb1aa40f661488e2782b6d57ad2f
#
#    age country_code                          Job Title  Country Age Group
# 0   62           AT  Automatic Data Processing Planner  Austria   [55-70)
# 1   53           AT  Automatic Data Processing Planner  Austria   [45-55)
# 2   50           AT                   Data Coordinator  Austria   [45-55)
# 3   51           AT                   Data Coordinator  Austria   [45-55)
# 4   46           AT                 Database Developer  Austria   [45-55)

# %%
grouped_df = definitive_df[['uuid','Country', 'Job Title','Age Group']].groupby(['Country', 'Job Title','Age Group']).count()
grouped_df.rename(columns={'uuid':'Quantity'}, inplace=True)
grouped_df['Percentage'] = grouped_df.groupby(level=0).transform(lambda x: x/x.sum())

# %%
grouped_df.head()
# Out:
#                                                                       Quantity  \
# Country Job Title                                          Age Group
# Austria Automatic Data Processing Customer Liaison (ADP... [40-45)           2
#         Automatic Data Processing Planner                  [45-55)           1
#                                                            [55-70)           1
#         Automatic Data Processing Systems Security Spec... [30-35)           1
#                                                            [45-55)           1
#
#                                                                       Percentage
# Country Job Title                                          Age Group
# Austria Automatic Data Processing Customer Liaison (ADP... [40-45)      0.027027
#         Automatic Data Processing Planner                  [45-55)      0.013514
#                                                            [55-70)      0.013514
#         Automatic Data Processing Systems Security Spec... [30-35)      0.013514
#                                                            [45-55)      0.013514

# %%
grouped_df = grouped_df.reset_index()

# %%
grouped_df.head()
# Out:
#    Country                                          Job Title Age Group  \
# 0  Austria  Automatic Data Processing Customer Liaison (AD...   [40-45)
# 1  Austria                  Automatic Data Processing Planner   [45-55)
# 2  Austria                  Automatic Data Processing Planner   [55-70)
# 3  Austria  Automatic Data Processing Systems Security Spe...   [30-35)
# 4  Austria  Automatic Data Processing Systems Security Spe...   [45-55)
#
#    Quantity  Percentage
# 0         2    0.027027
# 1         1    0.013514
# 2         1    0.013514
# 3         1    0.013514
# 4         1    0.013514

# %%
country = "Spain"

# %%
if country == "All":
    filtered_country_df = analyzed_df
else:
    filtered_country_df = grouped_df[grouped_df['Country']== country]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-c72fe4b9c0ff> in <module>
# ----> 1 if country == "All":
#       2     filtered_country_df = analyzed_df
#       3 else:
#       4     filtered_country_df = grouped_df[grouped_df['Country']== country]
#
# NameError: name 'country' is not defined

# %%
format_dict = {'Percentage': '{:.2%}'}
grouped_df = grouped_df.style.format(format_dict)

# %%
type(grouped_df)
# Out:
# pandas.io.formats.style.Styler

# %%
    if country == "All":
        filtered_country_df = analyzed_df
    else:
        filtered_country_df = analyzed_df[analyzed_df['Country']== country]
# Out:
# <style  type="text/css" >
# </style><table id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country</th>        <th class="col_heading level0 col1" >Job Title</th>        <th class="col_heading level0 col2" >Age Group</th>        <th class="col_heading level0 col3" >Quantity</th>        <th class="col_heading level0 col4" >Percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row0_col0" class="data row0 col0" >Spain</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row0_col1" class="data row0 col1" >Analytical Data Miner</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row0_col2" class="data row0 col2" >[30-35)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row0_col4" class="data row0 col4" >0.17%</td>
#             </tr>
#             <tr>
#                         <th id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row1_col0" class="data row1 col0" >Spain</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row1_col1" class="data row1 col1" >Automatic Data Processing Customer Liaison (ADP Customer Liaison)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row1_col2" class="data row1 col2" >(18-25)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row1_col4" class="data row1 col4" >0.17%</td>
#             </tr>
#             <tr>
#                         <th id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row2_col0" class="data row2 col0" >Spain</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row2_col1" class="data row2 col1" >Automatic Data Processing Customer Liaison (ADP Customer Liaison)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row2_col2" class="data row2 col2" >[30-35)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row2_col3" class="data row2 col3" >2</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row2_col4" class="data row2 col4" >0.34%</td>
#             </tr>
#             <tr>
#                         <th id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row3_col0" class="data row3 col0" >Spain</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row3_col1" class="data row3 col1" >Automatic Data Processing Customer Liaison (ADP Customer Liaison)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row3_col2" class="data row3 col2" >[40-45)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row3_col3" class="data row3 col3" >2</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row3_col4" class="data row3 col4" >0.34%</td>
#             </tr>
#             <tr>
#                         <th id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row4_col0" class="data row4 col0" >Spain</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row4_col1" class="data row4 col1" >Automatic Data Processing Customer Liaison (ADP Customer Liaison)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row4_col2" class="data row4 col2" >[45-55)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row4_col3" class="data row4 col3" >4</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row4_col4" class="data row4 col4" >0.69%</td>
#             </tr>
#             <tr>
#                         <th id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row5_col0" class="data row5 col0" >Spain</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row5_col1" class="data row5 col1" >Automatic Data Processing Customer Liaison (ADP Customer Liaison)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row5_col2" class="data row5 col2" >[55-70)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row5_col3" class="data row5 col3" >2</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row5_col4" class="data row5 col4" >0.34%</td>
#             </tr>
#             <tr>
#                         <th id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row6_col0" class="data row6 col0" >Spain</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row6_col1" class="data row6 col1" >Automatic Data Processing Planner</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row6_col2" class="data row6 col2" >[30-35)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row6_col3" class="data row6 col3" >1</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row6_col4" class="data row6 col4" >0.17%</td>
#             </tr>
#             <tr>
#                         <th id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row7_col0" class="data row7 col0" >Spain</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row7_col1" class="data row7 col1" >Automatic Data Processing Planner</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row7_col2" class="data row7 col2" >[40-45)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row7_col3" class="data row7 col3" >4</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row7_col4" class="data row7 col4" >0.69%</td>
#             </tr>
#             <tr>
#                         <th id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row8_col0" class="data row8 col0" >Spain</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row8_col1" class="data row8 col1" >Automatic Data Processing Planner</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row8_col2" class="data row8 col2" >[45-55)</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row8_col3" class="data row8 col3" >3</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row8_col4" class="data row8 col4" >0.52%</td>
#             </tr>
#             <tr>
#                         <th id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row9_col0" class="data row9 col0" >Spain</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row9_col1" class="data row9 col1" >Automatic Data Processing Planner</td>
#                         <td id="T_4ba80326_63d8_11eb_80d8_8f35a5b11339row9_col2" class="data row9 col2" >[55-70)</
